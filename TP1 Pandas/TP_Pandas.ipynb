# %%
import pandas as pd

# %%
df = pd.read_csv("./TP_Pandas/data.csv")
df
# Out:
#     prodparam  prodindic Class
# 0         2.0        9.0   NEG
# 1         8.0       39.0   NEG
# 2         1.0        NaN   NEG
# 3        56.0      279.0   POS
# 4         NaN       19.0   NEG
# 5        12.0       59.0   NEG
# 6        18.0       89.0   NEG
# 7        25.0      124.0   POS
# 8        46.0      229.0   POS
# 9        22.0      109.0   POS
# 10       78.0      389.0   POS
# 11       59.0        NaN   POS
# 12        NaN      174.0   POS
# 13       18.0       89.0   NEG
# 14       77.0      384.0   POS
# 15       96.0      479.0   POS
# 16       58.0      289.0   POS
# 17       46.0        NaN   POS
# 18       25.0      124.0   POS

# %%
df.head()
# Out:
#    prodparam  prodindic Class
# 0        2.0        9.0   NEG
# 1        8.0       39.0   NEG
# 2        1.0        NaN   NEG
# 3       56.0      279.0   POS
# 4        NaN       19.0   NEG

# %%
df.describe()
# Out:
#        prodparam   prodindic
# count  17.000000   16.000000
# mean   38.058824  180.250000
# std    28.953563  145.229703
# min     1.000000    9.000000
# 25%    18.000000   81.500000
# 50%    25.000000  124.000000
# 75%    58.000000  281.500000
# max    96.000000  479.000000

# %%
df.isna()
# Out:
#     prodparam  prodindic  Class
# 0       False      False  False
# 1       False      False  False
# 2       False       True  False
# 3       False      False  False
# 4        True      False  False
# 5       False      False  False
# 6       False      False  False
# 7       False      False  False
# 8       False      False  False
# 9       False      False  False
# 10      False      False  False
# 11      False       True  False
# 12       True      False  False
# 13      False      False  False
# 14      False      False  False
# 15      False      False  False
# 16      False      False  False
# 17      False       True  False
# 18      False      False  False

# %%
df.isna().sum()
# Out:
# prodparam    2
# prodindic    3
# Class        0
# dtype: int64

# %%
df.dtypes.value_counts().plot.pie()
# Out:
# <Axes: >

# %%
# Remplacement des nan par la valeur médiane
m = df.prodparam.median()
print(f"Médiane est {m}")
df.prodparam.fillna(m,inplace=True)
# Out:
# Médiane est 25.0

# %%
#Encodage
df.Class.replace({"POS":1,"NEG":0}, inplace=True)

# %%
moyen = df.prodparam.mean()
print(f"{moyen}")
# Out:
# 36.68421052631579

# %% [markdown]
# # Moyen pour chaque ligne (prodparam, prodindic)

# %%
df_moyen = ['prodparam', 'prodindic']
df["moyen"] = df[df_moyen].mean(axis=1)

# %%
df
# Out:
#     prodparam  prodindic  Class  moyen
# 0         2.0        9.0      0    5.5
# 1         8.0       39.0      0   23.5
# 2         1.0        NaN      0    1.0
# 3        56.0      279.0      1  167.5
# 4        25.0       19.0      0   22.0
# 5        12.0       59.0      0   35.5
# 6        18.0       89.0      0   53.5
# 7        25.0      124.0      1   74.5
# 8        46.0      229.0      1  137.5
# 9        22.0      109.0      1   65.5
# 10       78.0      389.0      1  233.5
# 11       59.0        NaN      1   59.0
# 12       25.0      174.0      1   99.5
# 13       18.0       89.0      0   53.5
# 14       77.0      384.0      1  230.5
# 15       96.0      479.0      1  287.5
# 16       58.0      289.0      1  173.5
# 17       46.0        NaN      1   46.0
# 18       25.0      124.0      1   74.5

# %%
def typage(x):
    if x > 80:
        return "apte"
    else:
        return "inapte"

# %%
typage(9)
# Out:
# 'inapte'

# %%
df["type"]
